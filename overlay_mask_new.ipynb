# %% [markdown]
# ### Use existing util
# This file tries to use the pytorch draw_segmentation_masks()
# https://www.analyticsvidhya.com/blog/2023/02/mask-r-cnn-for-instance-segmentation-using-pytorch/

# %%
import numpy as np

# %%
pred_mask_path = "/home/users/yitao/Code/VisTR/npy_for_mask_plot/pred_masks.npy"
pred_mask = np.load(pred_mask_path)

# %%
pred_mask.shape
# Out:
# (36, 10, 720, 1280)

# %%
import matplotlib.pyplot as plt

plt.imshow(pred_mask[5][7])

# %%
frame_num = 5
pred_mask[frame_num].shape
# Out:
# (10, 720, 1280)

# %%
mask_needed = pred_mask[5][7]
# type(mask_needed)
plt.imshow(mask_needed)

# %%
from torchvision.utils import draw_segmentation_masks
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/users/yitao/Code/VisTR/overlay_mask_new.ipynb Cell 8 in <module>
# ----> <a href='vscode-notebook-cell://ssh-remote%2Basu_c4n9/home/users/yitao/Code/VisTR/overlay_mask_new.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from torchvision.utils import draw_segmentation_masks
#
# ImportError: cannot import name 'draw_segmentation_masks' from 'torchvision.utils' (/home/users/yitao/.local/lib/python3.8/site-packages/torchvision/utils.py)
